# %%
import dspy
from dotenv import load_dotenv
import os

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
ANTHROPIC_API_KEY = os.getenv("ANTHROPIC_API_KEY")

#Define the differnet Models and Providers

localgpt = dspy.LM(
    model = "ollama/gpt-oss",
    api_base = "http://localhost:11434",
    api_key = "ollama"
)

localglm = dspy.LM(
    model = "glm-4.7-flash:q8_0",
    api_base = "http://localhost:11434",
    api_key = "ollama"
)

cloudgpt = dspy.LM(
    model = "openai/gpt-5.4",
    api_base = "https://api.openai.com/v1",
    api_key = OPENAI_API_KEY
)

cloudclaude = dspy.LM(
    model = "anthropic/claude-opus-4-6",
    #api_base = "https://api.anthropic.com",
    api_key = ANTHROPIC_API_KEY
)

models = [localgpt, localglm, cloudgpt, cloudclaude]

#define the Signatures

dspy.settings.configure(lm = models[0])

class Explain(dspy.Signature):
    topic = dspy.InputField()
    explanation = dspy.OutputField()

class Summarise(dspy.Signature):
    text = dspy.InputField()
    summary = dspy.OutputField()

class Explain_Summarise(dspy.Module):
    def __init__(self):
        self.explain = dspy.Predict(Explain)
        self.summarise = dspy.Predict(Summarise)

    def forward(self, topic):
        explanation = self.explain(topic = topic).explanation
        summary = self.summarise(text = explanation).summary
        return summary

# %%
#Define the Variables
question = input("What do you want to know? ")
for model in models:
    with dspy.context(lm = model):
        pipeline = Explain_Summarise()
        print(f"Model: {model}\nSummary: {pipeline(topic=question)}")
# Out:
# What do you want to know?  What is the difference between GEPA and JEPA
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       4 with dspy.context(lm = model.model):
#       5     pipeline = Explain_Summarise()
# ----> 6     print(f"Model: {model}\nSummary: {pipeline(topic=question)}")
#
# File ~/venvs/jupyter/lib/python3.12/site-packages/dspy/utils/callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~/venvs/jupyter/lib/python3.12/site-packages/dspy/primitives/module.py:82, in Module.__call__(self, *args, **kwargs)
#      78     self._set_lm_usage(tokens, output)
#      80     return output
# ---> 82 return self.forward(*args, **kwargs)
#
# Cell In[1], line 56, in Explain_Summarise.forward(self, topic)
#      55 def forward(self, topic):
# ---> 56     explanation = self.explain(topic = topic).explanation
#      57     summary = self.summarise(text = explanation).summary
#      58     return summary
#
# File ~/venvs/jupyter/lib/python3.12/site-packages/dspy/predict/predict.py:104, in Predict.__call__(self, *args, **kwargs)
#     101 if args:
#     102     raise ValueError(self._get_positional_args_error_message())
# --> 104 return super().__call__(**kwargs)
#
# File ~/venvs/jupyter/lib/python3.12/site-packages/dspy/utils/callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~/venvs/jupyter/lib/python3.12/site-packages/dspy/primitives/module.py:82, in Module.__call__(self, *args, **kwargs)
#      78     self._set_lm_usage(tokens, output)
#      80     return output
# ---> 82 return self.forward(*args, **kwargs)
#
# File ~/venvs/jupyter/lib/python3.12/site-packages/dspy/predict/predict.py:189, in Predict.forward(self, **kwargs)
#     188 def forward(self, **kwargs):
# --> 189     lm, config, signature, demos, kwargs = self._forward_preprocess(**kwargs)
#     191     adapter = settings.adapter or ChatAdapter()
#     193     if self._should_stream():
#
# File ~/venvs/jupyter/lib/python3.12/site-packages/dspy/predict/predict.py:131, in Predict._forward_preprocess(self, **kwargs)
#     123     raise ValueError(
#     124         "No LM is loaded. Please configure the LM using `dspy.configure(lm=dspy.LM(...))`. e.g, "
#     125         "`dspy.configure(lm=dspy.LM('openai/gpt-4o-mini'))`"
#     126     )
#     128 if isinstance(lm, str):
#     129     # Many users mistakenly use `dspy.configure(lm="openai/gpt-4o-mini")` instead of
#     130     # `dspy.configure(lm=dspy.LM("openai/gpt-4o-mini"))`, so we are providing a specific error message.
# --> 131     raise ValueError(
#     132         f"LM must be an instance of `dspy.BaseLM`, not a string. Instead of using a string like "
#     133         f"'dspy.configure(lm=\"{lm}\")', please configure the LM like 'dspy.configure(lm=dspy.LM(\"{lm}\"))'"
#     134     )
#     135 elif not isinstance(lm, BaseLM):
#     136     raise ValueError(f"LM must be an instance of `dspy.BaseLM`, not {type(lm)}. Received `lm={lm}`.")
#
# ValueError: LM must be an instance of `dspy.BaseLM`, not a string. Instead of using a string like 'dspy.configure(lm="ollama/gpt-oss")', please configure the LM like 'dspy.configure(lm=dspy.LM("ollama/gpt-oss"))'
